# %% [markdown]
# # DAP2
# ### Preprocessing and Exploratory Analysis
# John Munar and Jack Witt
#
# In this phase of the project, we examined, cleaned, and selected relevant features for both our datasets. Additionally, we performed an exploratory analysis and visualization to assess trends and patterns within our datasets.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("rawdata/2018_Financial_Data.csv")
df2 = pd.read_csv("rawdata/aapl.us.txt")

# %%
display(df)

df.shape
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0         CMCSA  9.450700e+10          0.1115     0.000000e+00  9.450700e+10
# 1           KMI  1.414400e+10          0.0320     7.288000e+09  6.856000e+09
# 2          INTC  7.084800e+10          0.1289     2.711100e+10  4.373700e+10
# 3            MU  3.039100e+10          0.4955     1.250000e+10  1.789100e+10
# 4            GE  1.216150e+11          0.0285     9.546100e+10  2.615400e+10
# ...         ...           ...             ...              ...           ...
# 4387       YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 4388       YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# 4389       ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# 4390        ZOM  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 4391       ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
# ...

# %%
for col in df.columns:
    s = str(col).lower()
    if 'growth' in s:
        #print(df[col].describe())
        print(col)
# Out:
# Revenue Growth
# priceEarningsToGrowthRatio
# Gross Profit Growth
# EBIT Growth
# Operating Income Growth
# Net Income Growth
# EPS Growth
# EPS Diluted Growth
# Weighted Average Shares Growth
# Weighted Average Shares Diluted Growth
# Dividends per Share Growth
# Operating Cash Flow growth
# Free Cash Flow growth
# 10Y Revenue Growth (per Share)
# 5Y Revenue Growth (per Share)
# 3Y Revenue Growth (per Share)
# 10Y Operating CF Growth (per Share)
# 5Y Operating CF Growth (per Share)
# 3Y Operating CF Growth (per Share)
# 10Y Net Income Growth (per Share)
# 5Y Net Income Growth (per Share)
# 3Y Net Income Growth (per Share)
# 10Y Shareholders Equity Growth (per Share)
# 5Y Shareholders Equity Growth (per Share)
# 3Y Shareholders Equity Growth (per Share)
# 10Y Dividend per Share Growth (per Share)
# 5Y Dividend per Share Growth (per Share)
# 3Y Dividend per Share Growth (per Share)
# Receivables growth
# Inventory Growth
# Asset Growth
# Book Value per Share Growth
# Debt Growth
# ...

# %%
indicators = ['Dividends per Share Growth', 
              '3Y Revenue Growth (per Share)', 
              'EPS Growth', 
              'Net Income Growth',
              'priceEarningsToGrowthRatio',
              '3Y Operating CF Growth (per Share)',
              '3Y Net Income Growth (per Share)',
              '3Y Shareholders Equity Growth (per Share)',
              '3Y Dividend per Share Growth (per Share)',
              'Book Value per Share',
              'Debt Growth',
              'Class']
for c in indicators:
    print(df[c].describe())
    print('NaN :',df[c].isna().sum())
# Out:
# count    4129.000000
# mean        0.136031
# std         2.323152
# min        -1.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.047600
# max       130.025000
# Name: Dividends per Share Growth, dtype: float64
# NaN : 263
# count    3960.000000
# mean        0.049008
# std         0.445685
# min        -1.000000
# 25%        -0.018125
# 50%         0.040000
# 75%         0.107425
# max        13.336800
# Name: 3Y Revenue Growth (per Share), dtype: float64
# NaN : 432
# count    4261.000000
# mean        0.551279
# std        13.157888
# min      -332.000000
# 25%        -0.324800
# 50%         0.185700
# 75%         0.693300
# max       395.791700
# Name: EPS Growth, dtype: float64
# NaN : 131
# count    4162.000000
# mean        1.424041
# std        62.949132
# min     -2036.750000
# 25%        -0.379725
# 50%         0.148250
# 75%         0.684250
# max      3159.000000
# Name: Net Income Growth, dtype: float64
# NaN : 230
# count    2734.000000
# ...

# %%
for col in df.columns:
    s = str(col).lower()
    if 'eps' in s:
        print(col)
# Out:
# EPS
# EPS Diluted
# EPS Growth
# EPS Diluted Growth

# %%
df['priceEarningsRatio'].isna().sum()
# Out:
# 252

# %%
df['EPS Growth'].isna().sum()
# Out:
# 131

# %%
# use these two to replace existing PEG values

# %%
display(df2)
df2.shape
# Out:
#             Date       Open       High        Low      Close    Volume  \
# 0     1984-09-07    0.42388    0.42902    0.41874    0.42388  23220030
# 1     1984-09-10    0.42388    0.42516    0.41366    0.42134  18022532
# 2     1984-09-11    0.42516    0.43668    0.42516    0.42902  42498199
# 3     1984-09-12    0.42902    0.43157    0.41618    0.41618  37125801
# 4     1984-09-13    0.43927    0.44052    0.43927    0.43927  57822062
# ...          ...        ...        ...        ...        ...       ...
# 8359  2017-11-06  171.75000  174.36000  171.10000  173.63000  34901241
# 8360  2017-11-07  173.29000  174.51000  173.29000  174.18000  24424877
# 8361  2017-11-08  174.03000  175.61000  173.71000  175.61000  24451166
# 8362  2017-11-09  174.48000  175.46000  172.52000  175.25000  29533086
# 8363  2017-11-10  175.11000  175.38000  174.27000  174.67000  25130494
#
#       OpenInt
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# ...

# %%
df2.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8364.000000  8364.000000  8364.000000  8364.000000  8.364000e+03
# mean     22.284350    22.495867    22.054244    22.281018  1.066416e+08
# std      37.763402    38.057733    37.447432    37.764469  9.935187e+07
# min       0.233050     0.235640     0.230510     0.230510  0.000000e+00
# 25%       1.137100     1.164200     1.112800     1.137100  4.384365e+07
# 50%       1.632800     1.663400     1.600600     1.628250  7.481383e+07
# 75%      23.739000    23.930500    23.335750    23.694500  1.320534e+08
# max     175.110000   175.610000   174.270000   175.610000  2.069770e+09
#
#        OpenInt
# count   8364.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
# date open high low close -> predict closing price for next day
